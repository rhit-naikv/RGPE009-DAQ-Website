# %% [markdown]
# # INITIAL LOADING

# %%
# %load "data_stuff.py"
from numpy import int64
import pandas as pd
import matplotlib.pyplot as plt
import math

# importing the CANLOG09 csv file
df = pd.read_csv('log01.csv')

# df[' B0'] = df[' B0'].apply(int, base=16)
# df[' B1'] = df[' B1'].apply(int, base=16)
# df[' B2'] = df[' B2'].apply(int, base=16)
# df[' B3'] = df[' B3'].apply(int, base=16)
# df[' B4'] = df[' B4'].apply(int, base=16)
# df[' B5'] = df[' B5'].apply(int, base=16)

# b16 = lambda x: int(str(x),16)


# df[' B6'] = df[' B6'].apply(b16)
# df[' B7'] = df[' B7'].apply(b16)
# Out:
# C:\Users\naikv\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # BEGIN CLEANING

# %%
df
# Out:
#         Millis   ID  B0   B1   B2   B3   B4   B5   B6  B7
# 0        86329  500   4  NaN  NaN  NaN  NaN  NaN  NaN NaN
# 1        86330  504   0   1a    1  NaN  NaN  NaN  NaN NaN
# 2        86337  534  54    8  NaN  NaN  NaN  NaN  NaN NaN
# 3        86337  514   0    4    0  NaN  NaN  NaN  NaN NaN
# 4        86337  554   0    0    0    0  NaN  NaN  NaN NaN
# ...        ...  ...  ..  ...  ...  ...  ...  ...  ...  ..
# 107410  270145  548  0e   d0    0   35   c0    0  NaN NaN
# 107411  270152  500   4  NaN  NaN  NaN  NaN  NaN  NaN NaN
# 107412  270153  504   0   1a    1  NaN  NaN  NaN  NaN NaN
# 107413  270156  513   0    0    0    0  NaN  NaN  NaN NaN
# 107414  270162  50c  8e    1    0  NaN  NaN  NaN  NaN NaN
#
# [107415 rows x 10 columns]

# %%
df = df.set_index('Millis')

# %%
df.dtypes
# Out:
# ID     object
# B0     object
# B1     object
# B2     object
# B3     object
# B4     object
# B5     object
# B6     object
# B7    float64
# dtype: object

# %%
df = df.fillna('0')

# %%
df['B0'] = df['B0'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B1'] = df['B1'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B2'] = df['B2'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')    
df['B3'] = df['B3'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B4'] = df['B4'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B5'] = df['B5'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B6'] = df['B6'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')
df['B7'] = df['B7'].apply(lambda x: int(float(x)) if isinstance(x, float) else x).astype('object')

# %%
df
# Out:
#          ID  B0  B1 B2  B3  B4 B5 B6 B7
# Millis
# 86329   500   4   0  0   0   0  0  0  0
# 86330   504   0  1a  1   0   0  0  0  0
# 86337   534  54   8  0   0   0  0  0  0
# 86337   514   0   4  0   0   0  0  0  0
# 86337   554   0   0  0   0   0  0  0  0
# ...     ...  ..  .. ..  ..  .. .. .. ..
# 270145  548  0e  d0  0  35  c0  0  0  0
# 270152  500   4   0  0   0   0  0  0  0
# 270153  504   0  1a  1   0   0  0  0  0
# 270156  513   0   0  0   0   0  0  0  0
# 270162  50c  8e   1  0   0   0  0  0  0
#
# [107415 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['ID', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7'], dtype='object')

# %%
for k in range(len(df.columns.values)):
    new_col = df.columns.values[k].strip()
    old_col = df.columns.values[k]
    df[new_col] = df[old_col]
    df.drop(old_col, axis=1)

# %%
df.columns
# Out:
# Index(['ID', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7'], dtype='object')

# %%
df.head(8)
# Out:
#          ID  B0  B1 B2  B3  B4 B5 B6 B7
# Millis
# 86329   500   4   0  0   0   0  0  0  0
# 86330   504   0  1a  1   0   0  0  0  0
# 86337   534  54   8  0   0   0  0  0  0
# 86337   514   0   4  0   0   0  0  0  0
# 86337   554   0   0  0   0   0  0  0  0
# 86337   500   4   0  0   0   0  0  0  0
# 86337   54c  0c  c0  0  0c  90  0  0  0
# 86337   504   0  1a  1   0   0  0  0  0

# %%
def hex_to_binary(my_hexdata):
    scale = 16 ## equals to hexadecimal
    num_of_bits = 8
#     print(my_hexdata)
    return bin(int(my_hexdata, scale))[2:].zfill(num_of_bits)
    
# Taken from this StackOverflow post: https://stackoverflow.com/questions/1425493/convert-hex-to-binary

# %%
df.loc[:,['B0','B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']] = df.loc[:,['B0','B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']].applymap(str).applymap(hex_to_binary)

# %% [markdown]
# # END CLEANING

# %%
df
# Out:
#          ID        B0        B1        B2        B3        B4        B5  \
# Millis
# 86329   500  00000100  00000000  00000000  00000000  00000000  00000000
# 86330   504  00000000  00011010  00000001  00000000  00000000  00000000
# 86337   534  01010100  00001000  00000000  00000000  00000000  00000000
# 86337   514  00000000  00000100  00000000  00000000  00000000  00000000
# 86337   554  00000000  00000000  00000000  00000000  00000000  00000000
# ...     ...       ...       ...       ...       ...       ...       ...
# 270145  548  00001110  11010000  00000000  00110101  11000000  00000000
# 270152  500  00000100  00000000  00000000  00000000  00000000  00000000
# 270153  504  00000000  00011010  00000001  00000000  00000000  00000000
# 270156  513  00000000  00000000  00000000  00000000  00000000  00000000
# 270162  50c  10001110  00000001  00000000  00000000  00000000  00000000
#
#               B6        B7
# Millis
# 86329   00000000  00000000
# 86330   00000000  00000000
# ...

# %%
front_controls = df[df['ID'] == '500'].copy()

# %%
front_controls['START'] = front_controls['B0'].apply(lambda x: x[1]).apply(lambda x: int(x, 2))
front_controls['STOP'] = front_controls['B0'].apply(lambda x: x[2]).apply(lambda x: int(x, 2))
front_controls['ESTOP'] = front_controls['B0'].apply(lambda x: x[3]).apply(lambda x: int(x, 2))
front_controls['Rotary Position Switch'] = front_controls['B0'].apply(lambda x: x[4 : 8]).apply(lambda x: int(x, 2))

# %%
front_controls
# Out:
#          ID        B0        B1        B2        B3        B4        B5  \
# Millis
# 86329   500  00000100  00000000  00000000  00000000  00000000  00000000
# 86337   500  00000100  00000000  00000000  00000000  00000000  00000000
# 86343   500  00000100  00000000  00000000  00000000  00000000  00000000
# 86354   500  00000100  00000000  00000000  00000000  00000000  00000000
# 86365   500  00000100  00000000  00000000  00000000  00000000  00000000
# ...     ...       ...       ...       ...       ...       ...       ...
# 270107  500  00000100  00000000  00000000  00000000  00000000  00000000
# 270119  500  00000100  00000000  00000000  00000000  00000000  00000000
# 270130  500  00000100  00000000  00000000  00000000  00000000  00000000
# 270143  500  00000100  00000000  00000000  00000000  00000000  00000000
# 270152  500  00000100  00000000  00000000  00000000  00000000  00000000
#
#               B6        B7  START  STOP  ESTOP  Rotary Position Switch
# Millis
# ...

# %%
front_controls[front_controls['START'] == 1]
# Out:
#          ID        B0        B1        B2        B3        B4        B5  \
# Millis
# 94459   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94470   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94481   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94492   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94503   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94515   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94525   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94536   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94547   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94558   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94569   500  01000100  00000000  00000000  00000000  00000000  00000000
# 94580   500  01000100  00000000  00000000  00000000  00000000  00000000
# ...

# %%
pt = pd.pivot_table(front_controls, values=['START', 'STOP', 'ESTOP', 'Rotary Position Switch'], index='Millis')

# %%
pt.plot(figsize = (20, 10))#.set_xlim(250000, 275000)
# Out:
# <AxesSubplot:xlabel='Millis'>

# %%
Clutch = df[df['ID'] == '510'].copy()

# %%
Clutch
# Out:
#          ID        B0        B1        B2        B3        B4        B5  \
# Millis
# 86403   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86506   510  01110111  00000101  00000000  00000000  00000000  00000000
# 86606   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86707   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86809   510  01111000  00000101  00000000  00000000  00000000  00000000
# ...     ...       ...       ...       ...       ...       ...       ...
# 269700  510  01111100  00000101  00000000  00000000  00000000  00000000
# 269801  510  01111101  00000101  00000000  00000000  00000000  00000000
# 269902  510  01111100  00000101  00000000  00000000  00000000  00000000
# 270003  510  01111011  00000101  00000000  00000000  00000000  00000000
# 270106  510  01111100  00000101  00000000  00000000  00000000  00000000
#
#               B6        B7
# Millis
# 86403   00000000  00000000
# 86506   00000000  00000000
# ...

# %%
Clutch['Clutch_Potentiometer'] = (Clutch['B1'].apply(lambda x: x[4:8]) + Clutch['B0']).apply(lambda x: int(x, 2))

# %%
Clutch
# Out:
#          ID        B0        B1        B2        B3        B4        B5  \
# Millis
# 86403   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86506   510  01110111  00000101  00000000  00000000  00000000  00000000
# 86606   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86707   510  01111000  00000101  00000000  00000000  00000000  00000000
# 86809   510  01111000  00000101  00000000  00000000  00000000  00000000
# ...     ...       ...       ...       ...       ...       ...       ...
# 269700  510  01111100  00000101  00000000  00000000  00000000  00000000
# 269801  510  01111101  00000101  00000000  00000000  00000000  00000000
# 269902  510  01111100  00000101  00000000  00000000  00000000  00000000
# 270003  510  01111011  00000101  00000000  00000000  00000000  00000000
# 270106  510  01111100  00000101  00000000  00000000  00000000  00000000
#
#               B6        B7  Clutch_Potentiometer
# Millis
# ...

# %%
pt = pd.pivot_table(Clutch, values=['Clutch_Potentiometer'], index='Millis')

# %%
pt['Millis'] = pt.index

# %%
pt.plot.scatter(x='Millis', y = 'Clutch_Potentiometer', figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Millis', ylabel='Clutch_Potentiometer'>
